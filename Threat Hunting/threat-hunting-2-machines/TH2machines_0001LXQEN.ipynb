# %%
# MRCI Threat Hunting - Perform Threat Hunting On 2 Machines

# import dependencies
import pandas as pd
import pyarrow as pa
import pyarrow.parquet as pq

pd.set_option('display.max_colwidth', None)

# convert Parquet file into a dataset
# change backslashes in copied file path to forward slashes to prevent Unicode escape sequence errors 
# cannot use hyphens '-' in variable names
domainusers_dataset = pq.ParquetDataset('C:/Users/bboyz/OneDrive/Desktop/MCSI Remote Cybersecurity Internship/Threat Hunting/mcsithreathunting2machines/domain_users.parquet')
loggedonusers_dataset = pq.ParquetDataset('C:/Users/bboyz/OneDrive/Desktop/MCSI Remote Cybersecurity Internship/Threat Hunting/mcsithreathunting2machines/loggedonusers/0001LXQEN.parquet')
useraccounts_dataset = pq.ParquetDataset('C:/Users/bboyz/OneDrive/Desktop/MCSI Remote Cybersecurity Internship/Threat Hunting/mcsithreathunting2machines/useraccounts/0001LXQEN.parquet')
w32drivers_dataset = pq.ParquetDataset('C:/Users/bboyz/OneDrive/Desktop/MCSI Remote Cybersecurity Internship/Threat Hunting/mcsithreathunting2machines/w32drivers/0001LXQEN.parquet')
w32persistence_fileitems_dataset = pq.ParquetDataset('C:/Users/bboyz/OneDrive/Desktop/MCSI Remote Cybersecurity Internship/Threat Hunting/mcsithreathunting2machines/w32persistencefileitems/0001LXQEN.parquet')
w32persistence_registryitems_dataset = pq.ParquetDataset('C:/Users/bboyz/OneDrive/Desktop/MCSI Remote Cybersecurity Internship/Threat Hunting/mcsithreathunting2machines/w32persistenceregistryitems/0001LXQEN.parquet')
w32persistence_servicesitems_dataset = pq.ParquetDataset('C:/Users/bboyz/OneDrive/Desktop/MCSI Remote Cybersecurity Internship/Threat Hunting/mcsithreathunting2machines/w32persistenceservicesitems/0001LXQEN.parquet')
w32processes_dataset = pq.ParquetDataset('C:/Users/bboyz/OneDrive/Desktop/MCSI Remote Cybersecurity Internship/Threat Hunting/mcsithreathunting2machines/w32processes/0001LXQEN.parquet')
w32processes_memorysections_dataset = pq.ParquetDataset('C:/Users/bboyz/OneDrive/Desktop/MCSI Remote Cybersecurity Internship/Threat Hunting/mcsithreathunting2machines/w32processesmemorysections/0001LXQEN.parquet')
w32services_dataset = pq.ParquetDataset('C:/Users/bboyz/OneDrive/Desktop/MCSI Remote Cybersecurity Internship/Threat Hunting/mcsithreathunting2machines/w32services/0001LXQEN.parquet')
w32tasks_dataset = pq.ParquetDataset('C:/Users/bboyz/OneDrive/Desktop/MCSI Remote Cybersecurity Internship/Threat Hunting/mcsithreathunting2machines/w32tasks/0001LXQEN.parquet')

# convert dataset into pandas
domainusers = domainusers_dataset.read().to_pandas()
loggedonusers = loggedonusers_dataset.read().to_pandas()
useraccounts = useraccounts_dataset.read().to_pandas()
w32drivers = w32drivers_dataset.read().to_pandas()
w32persistence_fileitems = w32persistence_fileitems_dataset.read().to_pandas()
w32persistence_registryitems = w32persistence_registryitems_dataset.read().to_pandas()
w32persistence_servicesitems = w32persistence_servicesitems_dataset.read().to_pandas()
w32processes = w32processes_dataset.read().to_pandas()
w32processes_memorysections = w32processes_memorysections_dataset.read().to_pandas()
w32services = w32services_dataset.read().to_pandas()
w32tasks = w32tasks_dataset.read().to_pandas()

# %%
domainusers
# Out:
#                group       username
# 0              seoul     timotlopez
# 1              seoul     timotlopez
# 2              seoul     timotlopez
# 3      domain admins     timotlopez
# 4      domain admins  Administrator
# 5  enterprise admins         svc_lw

# %%
loggedonusers
# Out:
#     domain-user   hostname  local-user                 username
# 0         False  0001LXQEN        True              svchost.exe
# 1         False  0001LXQEN        True             winlogon.exe
# 2         False  0001LXQEN        True        RuntimeBroker.exe
# 3         False  0001LXQEN        True                lsass.exe
# 4         False  0001LXQEN        True                  dwm.exe
# 5         False  0001LXQEN        True              conhost.exe
# 6         False  0001LXQEN        True              LogonUI.exe
# 7         False  0001LXQEN        True              spoolsv.exe
# 8         False  0001LXQEN        True              dllhost.exe
# 9         False  0001LXQEN        True                msdtc.exe
# 10        False  0001LXQEN        True            taskhostw.exe
# 11        False  0001LXQEN        True               sihost.exe
# 12        False  0001LXQEN        True             Explorer.EXE
# 13        False  0001LXQEN        True             TabTip32.exe
# 14        False  0001LXQEN        True             MpCmdRun.exe
# 15        False  0001LXQEN        True  ShellExperienceHost.exe
# 16        False  0001LXQEN        True             SearchUI.exe
# 17         True  0001LXQEN       False               timotlopez
# 18        False  0001LXQEN        True              AvastUI.exe
# 19        False  0001LXQEN        True             AvastSvc.exe
# 20        False  0001LXQEN        True             OneDrive.exe
# 21        False  0001LXQEN        True             iexplore.exe
# 22        False  0001LXQEN        True              mspaint.exe
# 23        False  0001LXQEN        True                  cmd.exe
# 24        False  0001LXQEN        True                 ruby.exe
# 25         True  0001LXQEN       False            Administrator
# 26        False  0001LXQEN        True           CCleaner64.exe
# 27        False  0001LXQEN        True   CyberGhost.Service.exe
# 28        False  0001LXQEN        True            KeePassXC.exe

# %%
useraccounts
# Out:
#    domain-admin  domain-user   hostname  local-admin  local-user  \
# 0          True         True  0001LXQEN        False       False
# 1          True         True  0001LXQEN         True       False
#
#         username
# 0  Administrator
# 1     timotlopez

# %%
# Filter rows where modulepath does not contain 'drivers'
non_driver_paths = w32drivers[~w32drivers['modulepath'].str.contains(r'\\drivers\\', na=False, case=False)]

print("Modules not in drivers folder:")
print(non_driver_paths)
# Out:
# Modules not in drivers folder:
#       hostname        modulename  \
# 10   0001LXQEN    win32kfull.sys
# 20   0001LXQEN  CompositeBus.sys
# 24   0001LXQEN           cdd.dll
# 25   0001LXQEN         kdcom.dll
# 42   0001LXQEN         PSHED.dll
# 47   0001LXQEN      ntoskrnl.exe
# 54   0001LXQEN      mcupdate.dll
# 73   0001LXQEN        RDPUDD.dll
# 74   0001LXQEN    win32kbase.sys
# 94   0001LXQEN        win32k.sys
# 104  0001LXQEN         TSDDD.dll
# 108  0001LXQEN       BOOTVID.dll
# 109  0001LXQEN            CI.dll
# 119  0001LXQEN           hal.dll
#
#                                             modulepath
# 10                                C:\Windows\System32\
# 20   C:\Windows\System32\DriverStore\FileRepository...
# 24                                C:\Windows\System32\
# 25                                   C:\Windows\system
# 42                                C:\Windows\system32\
# 47                                C:\Windows\system32\
# 54                   C:\Windows\system32\mcupdate_Genu
# 73                                C:\Windows\System32\
# 74                                C:\Windows\System32\
# 94                                C:\Windows\System32\
# 104                               C:\Windows\System32\
# 108                               C:\Windows\system32\
# 109                               C:\Windows\system32\
# 119                               C:\Windows\system32\

# %%
# Filter for suspicious drivers
suspicious_drivers_modulename = w32drivers[
    (w32drivers['modulename'].str.contains(r'(?:debug|hook|dump|malware|rootkit)', na=False, case=False))
]

print("Suspicious Drivers Module Names:")
print(suspicious_drivers_modulename)
# Out:
# Suspicious Drivers Module Names:
#      hostname         modulename                    modulepath
# 13  0001LXQEN   dump_vioscsi.sys  C:\Windows\System32\Drivers\
# 72  0001LXQEN  dump_storport.sys  C:\Windows\System32\Drivers\

# %%
# List of suspicious executables
suspicious_executables = r'(?:narrator\.exe|sethc\.exe|utilman\.exe|osk\.exe|searchui\.exe|magnify\.exe|calculator\.exe)'

# Filter rows where the 'filename' column contains any of the suspicious executables
suspicious_files = w32persistence_fileitems[w32persistence_fileitems['filename'].str.contains(suspicious_executables, na=False, case=False)]

print("Suspicious Files:")
print(suspicious_files)
# Out:
# Suspicious Files:
# Empty DataFrame
# Columns: [drive, fileextension, filename, filepath, fullpath, hostname, username]
# Index: []

# %%
# List of suspicious terms for registry analysis
suspicious_terms = r'(?:password)'

# Apply filtering on the dataframe
suspicious_registry_items = w32persistence_registryitems[
    w32persistence_registryitems.apply(lambda row: row.astype(str).str.contains(suspicious_terms, na=False, case=False).any(), axis=1)
]

# Print suspicious registry items
print("Suspicious Registry Items:")
print(suspicious_registry_items)
# Out:
# Suspicious Registry Items:
#        hostname  \
# 567   0001LXQEN
# 3260  0001LXQEN
#
#                                                                   keypath  \
# 567   Classes\CLSID\{9fb45d27-dfe3-4383-b117-ab631787649a}\InProcServer32
# 3260  Classes\CLSID\{0fafd998-c8e8-42a1-86d7-7c10c664a415}\InProcServer32
#
#                                                                                                   path  \
# 567   HKEY_LOCAL_MACHINE\Software\Classes\CLSID\{9fb45d27-dfe3-4383-b117-ab631787649a}\InProcServer32\
# 3260  HKEY_LOCAL_MACHINE\Software\Classes\CLSID\{0fafd998-c8e8-42a1-86d7-7c10c664a415}\InProcServer32\
#
#                                                       text           type  \
# 567   %SystemRoot%\system32\windows.ui.picturepassword.dll  REG_EXPAND_SZ
# 3260  %SystemRoot%\system32\windows.ui.picturepassword.dll  REG_EXPAND_SZ
#
#                  username valuename
# 567   NT AUTHORITY\SYSTEM
# 3260  NT AUTHORITY\SYSTEM

# %%
# List of suspicious terms
suspicious_terms = r'(?:reg\.exe|ServiceName|Reg query|HKCU|HKLM|Lsass\.exe|HKEY|PuTTY|SAM|kerberos)'

# Apply filtering on the dataframe
suspicious_processes = w32processes[
    w32processes.apply(lambda row: row.astype(str).str.contains(suspicious_terms, na=False, case=False).any(), axis=1)
]

# Print suspicious processes
print("Suspicious Processes:")
print(suspicious_processes)
# Out:
# Suspicious Processes:
#                         arguments   hostname       name                 path  \
# 43  C:\Windows\system32\lsass.exe  0001LXQEN  lsass.exe  C:\Windows\system32
#
#      pid             username
# 43  4636  NT AUTHORITY\SYSTEM

# %%
# List of suspicious executables
suspicious_executables = r'(?:narrator\.exe|sethc\.exe|utilman\.exe|osk\.exe|searchui\.exe|magnify\.exe|calculator\.exe)'

# Filter rows in w32processes dataset
suspicious_processes = w32processes[
    w32processes['name'].str.contains(suspicious_executables, na=False, case=False)
]

print("Suspicious Processes:")
print(suspicious_processes)
# Out:
# Suspicious Processes:
#                                                                                                                                       arguments  \
# 27  "C:\Windows\SystemApps\Microsoft.Windows.Cortana_cw5n1h2txyewy\SearchUI.exe" -ServerName:CortanaUI.AppXa50dqqa5gqv4a428c9y1jjw7m3btvepj.mca
#
#      hostname          name  \
# 27  0001LXQEN  SearchUI.exe
#
#                                                              path   pid  \
# 27  C:\Windows\SystemApps\Microsoft.Windows.Cortana_cw5n1h2txyewy  5868
#
#                username
# 27  NT AUTHORITY\SYSTEM

# %%
# List of suspicious executables
suspicious_executables = r'(?:narrator\.exe|sethc\.exe|utilman\.exe|osk\.exe|searchui\.exe|magnify\.exe|calculator\.exe)'

# Filter rows in w32drivers dataset
suspicious_drivers = w32drivers[
    w32drivers['modulename'].str.contains(suspicious_executables, na=False, case=False)
]

print("Suspicious Drivers:")
print(suspicious_drivers)
# Out:
# Suspicious Drivers:
# Empty DataFrame
# Columns: [hostname, modulename, modulepath]
# Index: []

# %%
# List of suspicious executables
suspicious_executables = r'(?:narrator\.exe|sethc\.exe|utilman\.exe|osk\.exe|searchui\.exe|magnify\.exe|calculator\.exe)'

# Filter rows in w32persistence_fileitems dataset
suspicious_files = w32persistence_fileitems[
    w32persistence_fileitems['filename'].str.contains(suspicious_executables, na=False, case=False)
]

print("Suspicious Files:")
print(suspicious_files)
# Out:
# Suspicious Files:
# Empty DataFrame
# Columns: [drive, fileextension, filename, filepath, fullpath, hostname, username]
# Index: []

# %%
# List of suspicious terms
suspicious_terms_registry = r'(?:sc|binPath|HKLM|ImagePath|FailureCommand|HKEY|svchost\.exe|winlogon\.exe|regedit\.exe)'

# Filter rows in w32persistence_registryitems dataset
suspicious_registry_items = w32persistence_registryitems[
    w32persistence_registryitems.apply(
        lambda row: row.astype(str).str.contains(suspicious_terms_registry, na=False, case=False).any(),
        axis=1
    )
]

# Print suspicious rows from the registry items
print("Suspicious Registry Items:")
print(suspicious_registry_items)
# Out:
# Suspicious Registry Items:
#        hostname  \
# 0     0001LXQEN
# 1     0001LXQEN
# 2     0001LXQEN
# 3     0001LXQEN
# 4     0001LXQEN
# ...         ...
# 6099  0001LXQEN
# 6100  0001LXQEN
# 6101  0001LXQEN
# 6102  0001LXQEN
# 6103  0001LXQEN
#
#                                                                               keypath  \
# 0                 Classes\CLSID\{4be5c3b3-53a2-4f2f-af9d-d26a5327eb92}\InProcServer32
# 1                 Classes\CLSID\{ed9d80b9-d157-457b-9192-0e7280313bf0}\InProcServer32
# 2     Wow6432Node\Classes\CLSID\{3F037241-414E-11D1-A7CE-00A0C913F73C}\InProcServer32
# 3                 Classes\CLSID\{46080CA7-7CB8-3A55-A72E-8E50ECA4D4FC}\InProcServer32
# 4                 Classes\CLSID\{0C1A0EF4-B44F-4179-BDDD-31C27DE7A6D1}\InProcServer32
# ...                                                                               ...
# 6099              Classes\CLSID\{B92E345D-F52D-41F3-B562-081BC772E3B9}\InProcServer32
# 6100              Classes\CLSID\{3050f6cd-98b5-11cf-bb82-00aa00bdce0b}\InProcServer32
# 6101              Classes\CLSID\{b27b520e-46db-4720-b9c5-5f80acab23a4}\InProcServer32
# 6102              Classes\CLSID\{9456A480-E88B-43EA-9E73-0B2D9B71B1CA}\InProcServer32
# 6103              Classes\CLSID\{32DA2B15-CFED-11D1-B747-00C04FC2B085}\InProcServer32
#
#                                                                                                               path  \
# 0                 HKEY_LOCAL_MACHINE\Software\Classes\CLSID\{4be5c3b3-53a2-4f2f-af9d-d26a5327eb92}\InProcServer32\
# 1                 HKEY_LOCAL_MACHINE\Software\Classes\CLSID\{ed9d80b9-d157-457b-9192-0e7280313bf0}\InProcServer32\
# 2     HKEY_LOCAL_MACHINE\Software\Wow6432Node\Classes\CLSID\{3F037241-414E-11D1-A7CE-00A0C913F73C}\InProcServer32\
# 3                 HKEY_LOCAL_MACHINE\Software\Classes\CLSID\{46080CA7-7CB8-3A55-A72E-8E50ECA4D4FC}\InProcServer32\
# 4                 HKEY_LOCAL_MACHINE\Software\Classes\CLSID\{0C1A0EF4-B44F-4179-BDDD-31C27DE7A6D1}\InProcServer32\
# ...                                                                                                            ...
# 6099              HKEY_LOCAL_MACHINE\Software\Classes\CLSID\{B92E345D-F52D-41F3-B562-081BC772E3B9}\InProcServer32\
# 6100              HKEY_LOCAL_MACHINE\Software\Classes\CLSID\{3050f6cd-98b5-11cf-bb82-00aa00bdce0b}\InProcServer32\
# 6101              HKEY_LOCAL_MACHINE\Software\Classes\CLSID\{b27b520e-46db-4720-b9c5-5f80acab23a4}\InProcServer32\
# 6102              HKEY_LOCAL_MACHINE\Software\Classes\CLSID\{9456A480-E88B-43EA-9E73-0B2D9B71B1CA}\InProcServer32\
# 6103              HKEY_LOCAL_MACHINE\Software\Classes\CLSID\{32DA2B15-CFED-11D1-B747-00C04FC2B085}\InProcServer32\
#
#                                                    text           type  \
# 0     C:\Windows\System32\IME\IMEKR\APPLETS\imkrskf.dll         REG_SZ
# 1                     %SystemRoot%\system32\zipfldr.dll  REG_EXPAND_SZ
# 2                     %SystemRoot%\System32\dmstyle.dll  REG_EXPAND_SZ
# 3                       C:\Windows\System32\mscoree.dll         REG_SZ
# 4             %SystemRoot%\System32\InternetMailCsp.dll  REG_EXPAND_SZ
# ...                                                 ...            ...
# 6099            %SystemRoot%\system32\windowscodecs.dll  REG_EXPAND_SZ
# 6100                    C:\Windows\System32\iepeers.dll         REG_SZ
# 6101                    %SystemRoot%\system32\hgcpl.dll  REG_EXPAND_SZ
# 6102            %SystemRoot%\system32\windowscodecs.dll  REG_EXPAND_SZ
# 6103                     C:\Windows\System32\scrrun.dll         REG_SZ
#
#                  username valuename
# 0     NT AUTHORITY\SYSTEM
# 1     NT AUTHORITY\SYSTEM
# 2     NT AUTHORITY\SYSTEM
# 3     NT AUTHORITY\SYSTEM
# 4     NT AUTHORITY\SYSTEM
# ...                   ...       ...
# 6099  NT AUTHORITY\SYSTEM
# 6100  NT AUTHORITY\SYSTEM
# 6101  NT AUTHORITY\SYSTEM
# 6102  NT AUTHORITY\SYSTEM
# 6103  NT AUTHORITY\SYSTEM
#
# [6086 rows x 7 columns]

# %%
# List of suspicious terms
suspicious_terms_services = r'(?:sc|binPath|HKLM|ImagePath|FailureCommand|HKEY|svchost\.exe|winlogon\.exe|regedit\.exe)'

# Filter rows in w32services dataset
suspicious_services = w32services[
    w32services.apply(
        lambda row: row.astype(str).str.contains(suspicious_terms_services, na=False, case=False).any(),
        axis=1
    )
]

# Print suspicious rows from the services
print("Suspicious Services:")
print(suspicious_services)
# Out:
# Suspicious Services:
#                                                               arguments  \
# 0                       C:\Windows\system32\svchost.exe -k LocalService
# 4    C:\Windows\system32\svchost.exe -k NetworkServiceNetworkRestricted
# 5                       C:\Windows\system32\svchost.exe -k LocalService
# 7       C:\Windows\system32\svchost.exe -k LocalSystemNetworkRestricted
# 9                       C:\Windows\System32\svchost.exe -k LocalService
# ..                                                                  ...
# 480                    C:\Windows\system32\svchost.exe -k AxInstSVGroup
# 481     C:\Windows\system32\svchost.exe -k LocalSystemNetworkRestricted
# 484       C:\Windows\Microsoft.NET\Framework64\v4.0.30319\SMSvcHost.exe
# 492                          C:\Windows\system32\svchost.exe -k netsvcs
# 494                              \SystemRoot\System32\drivers\bxois.sys
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           description  \
# 0                                                                                                                                                                                                                                                                                                                                                                                                                                                                            This service is used for Connected Devices and Universal Glass scenarios
# 4    "Internet Protocol security (IPsec) supports network-level peer authentication  data origin authentication  data integrity  data confidentiality (encryption)  and replay protection.  This service enforces IPsec policies created through the IP Security Policies snap-in or the command-line tool ""netsh ipsec"".  If you stop this service  you may experience network connectivity issues if your policy requires that connections use IPsec.  Also remote management of Windows Firewall is not available when this service is stopped."
# 5                                                                                                                                                                                                                                                                                        Maintains date and time synchronization on all clients and servers in the network. If this service is stopped  date and time synchronization will be unavailable. If this service is disabled  any services that explicitly depend on it will fail to start.
# 7                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              Enables apps to discover devices with a backgroud task
# 9                                                                                                                                                                                                                                                                                                                                                                             Identifies the networks to which the computer has connected  collects and stores properties for these networks  and notifies applications when these properties change.
# ..                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                ...
# 480                                                                                                                                                                                                              Provides User Account Control validation for the installation of ActiveX controls from the Internet and enables management of ActiveX control installation based on Group Policy settings. This service is started on demand and if disabled the installation of ActiveX controls will behave according to default browser settings.
# 481                                                                                                                                                                         A service for sensors that manages different sensors' functionality. Manages Simple Device Orientation (SDO) and History for sensors. Loads the SDO sensor that reports device orientation changes.  If this service is stopped or disabled  the SDO sensor will not be loaded and so auto-rotation will not occur. History collection from Sensors will also be stopped.
# 484                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    Provides ability to share TCP ports over the net.tcp protocol.
# 492                                                                                                                                                                                                                Enables a user to configure and schedule automated tasks on this computer. The service also hosts multiple Windows system-critical tasks. If this service is stopped or disabled  these tasks will not be run at their scheduled times. If this service is disabled  any services that explicitly depend on it will fail to start.
# 494
#
#                           descriptivename   hostname  \
# 0      Connected Devices Platform Service  0001LXQEN
# 4                      IPsec Policy Agent  0001LXQEN
# 5                            Windows Time  0001LXQEN
# 7    DevQuery Background Discovery Broker  0001LXQEN
# 9                    Network List Service  0001LXQEN
# ..                                    ...        ...
# 480          ActiveX Installer (AxInstSV)  0001LXQEN
# 481                        Sensor Service  0001LXQEN
# 484          Net.Tcp Port Sharing Service  0001LXQEN
# 492                        Task Scheduler  0001LXQEN
# 494           QLogic Offload iSCSI Driver  0001LXQEN
#
#                                   md5               name  \
# 0    d47954756fd41951ec94e2959a2c290e             CDPSvc
# 4    d47954756fd41951ec94e2959a2c290e        PolicyAgent
# 5    d47954756fd41951ec94e2959a2c290e            w32time
# 7    d47954756fd41951ec94e2959a2c290e     DevQueryBroker
# 9    d47954756fd41951ec94e2959a2c290e           netprofm
# ..                                ...                ...
# 480  d47954756fd41951ec94e2959a2c290e           AxInstSV
# 481  d47954756fd41951ec94e2959a2c290e      SensorService
# 484  d6dbba706556015e0b0be87675094806  NetTcpPortSharing
# 492  d47954756fd41951ec94e2959a2c290e           Schedule
# 494  0d66843548cb5adff276b4567d37692b              bxois
#
#                                                               path  \
# 0                                  C:\Windows\System32\svchost.exe
# 4                                  C:\Windows\System32\svchost.exe
# 5                                  C:\Windows\System32\svchost.exe
# 7                                  C:\Windows\System32\svchost.exe
# 9                                  C:\Windows\System32\svchost.exe
# ..                                                             ...
# 480                                C:\Windows\System32\svchost.exe
# 481                                C:\Windows\System32\svchost.exe
# 484  C:\Windows\Microsoft.NET\Framework64\v4.0.30319\SMSvcHost.exe
# 492                                C:\Windows\System32\svchost.exe
# 494                          C:\Windows\System32\drivers\bxois.sys
#
#                      pathcertificateissuer pathcertificatesubject  \
# 0    Microsoft Windows Production PCA 2011      Microsoft Windows
# 4    Microsoft Windows Production PCA 2011      Microsoft Windows
# 5    Microsoft Windows Production PCA 2011      Microsoft Windows
# 7    Microsoft Windows Production PCA 2011      Microsoft Windows
# 9    Microsoft Windows Production PCA 2011      Microsoft Windows
# ..                                     ...                    ...
# 480  Microsoft Windows Production PCA 2011      Microsoft Windows
# 481  Microsoft Windows Production PCA 2011      Microsoft Windows
# 484  Microsoft Windows Production PCA 2011      Microsoft Windows
# 492  Microsoft Windows Production PCA 2011      Microsoft Windows
# 494  Microsoft Windows Production PCA 2011      Microsoft Windows
#
#                                pathsignaturedescription pathsignatureexists  \
# 0    The file is signed and the signature was verified.                true
# 4    The file is signed and the signature was verified.                true
# 5    The file is signed and the signature was verified.                true
# 7    The file is signed and the signature was verified.                true
# 9    The file is signed and the signature was verified.                true
# ..                                                  ...                 ...
# 480  The file is signed and the signature was verified.                true
# 481  The file is signed and the signature was verified.                true
# 484  The file is signed and the signature was verified.                true
# 492  The file is signed and the signature was verified.                true
# 494  The file is signed and the signature was verified.                true
#
#     pathsignatureverified                              servicedll  \
# 0                    true          C:\Windows\System32\cdpsvc.dll
# 4                    true        C:\Windows\System32\IPSECSVC.DLL
# 5                    true         C:\Windows\System32\w32time.dll
# 7                    true  C:\Windows\System32\DevQueryBroker.dll
# 9                    true     C:\Windows\System32\netprofmsvc.dll
# ..                    ...                                     ...
# 480                  true        C:\Windows\System32\AxInstSv.dll
# 481                  true   C:\Windows\System32\SensorService.dll
# 484                  true
# 492                  true        C:\Windows\System32\schedsvc.dll
# 494                  true
#
#                             type
# 0    SERVICE_WIN32_SHARE_PROCESS
# 4    SERVICE_WIN32_SHARE_PROCESS
# 5    SERVICE_WIN32_SHARE_PROCESS
# 7    SERVICE_WIN32_SHARE_PROCESS
# 9    SERVICE_WIN32_SHARE_PROCESS
# ..                           ...
# 480  SERVICE_WIN32_SHARE_PROCESS
# 481  SERVICE_WIN32_SHARE_PROCESS
# 484  SERVICE_WIN32_SHARE_PROCESS
# 492  SERVICE_WIN32_SHARE_PROCESS
# 494        SERVICE_KERNEL_DRIVER
#
# [186 rows x 14 columns]

# %%
# List of suspicious terms
suspicious_terms_registry = r'(?:sc|binPath|HKLM|ImagePath|FailureCommand|HKEY|svchost\.exe|winlogon\.exe|regedit\.exe)'

# Filter rows in w32persistence_registryitems dataset
suspicious_registry_items = w32persistence_registryitems[
    w32persistence_registryitems.apply(
        lambda row: row.astype(str).str.contains(suspicious_terms_registry, na=False, case=False).any(),
        axis=1
    ) & (w32persistence_registryitems['username'] != 'NT AUTHORITY\\SYSTEM')  # Exclude rows with 'NT AUTHORITY\SYSTEM'
]

# Print suspicious rows from the registry items
print("Suspicious Registry Items (excluding NT AUTHORITY\SYSTEM):")
print(suspicious_registry_items)
# Out:
# Suspicious Registry Items (excluding NT AUTHORITY\SYSTEM):
#        hostname  \
# 379   0001LXQEN
# 1945  0001LXQEN
# 2465  0001LXQEN
# 2476  0001LXQEN
# 2960  0001LXQEN
# 3546  0001LXQEN
# 3612  0001LXQEN
# 3672  0001LXQEN
# 3737  0001LXQEN
# 4016  0001LXQEN
# 4710  0001LXQEN
# 5189  0001LXQEN
# 5539  0001LXQEN
#
#                                                                               keypath  \
# 379               Classes\CLSID\{472083B0-C522-11CF-8763-00608CC02F24}\InProcServer32
# 1945                                         CurrentControlSet\Services\aswbIDSAgent\
# 2465                                     CurrentControlSet\Services\avast! Antivirus\
# 2476  Wow6432Node\Classes\CLSID\{472083B0-C522-11CF-8763-00608CC02F24}\InProcServer32
# 2960                                               CurrentControlSet\Services\rdpbus\
# 3546              Classes\CLSID\{9209B7D1-6DA5-43E4-BCD1-F2BE497635E7}\InProcServer32
# 3612              Classes\CLSID\{5828227c-20cf-4408-b73f-73ab70b8849f}\InProcServer32
# 3672              Classes\CLSID\{B342E21B-AD7E-4568-AE3F-D0D844537A7A}\InProcServer32
# 3737              Classes\CLSID\{FB904E4E-D2C7-4C8D-8492-B620BB9896B1}\InProcServer32
# 4016  Wow6432Node\Classes\CLSID\{7BFC2BD7-0937-41EA-8872-CE3B27E08F84}\InProcServer32
# 4710  Wow6432Node\Classes\CLSID\{3C5422B3-D1E2-449E-A736-809C934C2F80}\InProcServer32
# 5189  Wow6432Node\Classes\CLSID\{B342E21B-AD7E-4568-AE3F-D0D844537A7A}\InProcServer32
# 5539              Classes\CLSID\{3C5422B3-D1E2-449E-A736-809C934C2F80}\InProcServer32
#
#                                                                                                               path  \
# 379               HKEY_LOCAL_MACHINE\Software\Classes\CLSID\{472083B0-C522-11CF-8763-00608CC02F24}\InProcServer32\
# 1945                                   HKEY_LOCAL_MACHINE\SYSTEM\CurrentControlSet\Services\aswbIDSAgent\ImagePath
# 2465                               HKEY_LOCAL_MACHINE\SYSTEM\CurrentControlSet\Services\avast! Antivirus\ImagePath
# 2476  HKEY_LOCAL_MACHINE\Software\Wow6432Node\Classes\CLSID\{472083B0-C522-11CF-8763-00608CC02F24}\InProcServer32\
# 2960                                         HKEY_LOCAL_MACHINE\SYSTEM\CurrentControlSet\Services\rdpbus\ImagePath
# 3546              HKEY_LOCAL_MACHINE\Software\Classes\CLSID\{9209B7D1-6DA5-43E4-BCD1-F2BE497635E7}\InProcServer32\
# 3612              HKEY_LOCAL_MACHINE\Software\Classes\CLSID\{5828227c-20cf-4408-b73f-73ab70b8849f}\InProcServer32\
# 3672              HKEY_LOCAL_MACHINE\Software\Classes\CLSID\{B342E21B-AD7E-4568-AE3F-D0D844537A7A}\InProcServer32\
# 3737              HKEY_LOCAL_MACHINE\Software\Classes\CLSID\{FB904E4E-D2C7-4C8D-8492-B620BB9896B1}\InProcServer32\
# 4016  HKEY_LOCAL_MACHINE\Software\Wow6432Node\Classes\CLSID\{7BFC2BD7-0937-41EA-8872-CE3B27E08F84}\InProcServer32\
# 4710  HKEY_LOCAL_MACHINE\Software\Wow6432Node\Classes\CLSID\{3C5422B3-D1E2-449E-A736-809C934C2F80}\InProcServer32\
# 5189  HKEY_LOCAL_MACHINE\Software\Wow6432Node\Classes\CLSID\{B342E21B-AD7E-4568-AE3F-D0D844537A7A}\InProcServer32\
# 5539              HKEY_LOCAL_MACHINE\Software\Classes\CLSID\{3C5422B3-D1E2-449E-A736-809C934C2F80}\InProcServer32\
#
#                                                               text  \
# 379             C:\Program Files\AVAST Software\Avast\ashShA64.dll
# 1945  "C:\Program Files\AVAST Software\Avast\x64\aswidsagenta.exe"
# 2465          "C:\Program Files\AVAST Software\Avast\AvastSvc.exe"
# 2476            C:\Program Files\AVAST Software\Avast\ashShell.dll
# 2960                       \SystemRoot\System32\drivers\rdpbus.sys
# 3546                             %SystemRoot%\system32\rdpendp.dll
# 3612                               %windir%\system32\rdpcorets.dll
# 3672        C:\Program Files\AVAST Software\Avast\x64\asOutExt.dll
# 3737         C:\Program Files\AVAST Software\Avast\x64\aswAMSI.dll
# 4016              C:\Program Files\AVAST Software\Avast\AhAScr.dll
# 4710             C:\Program Files\AVAST Software\Avast\aswAMSI.dll
# 5189            C:\Program Files\AVAST Software\Avast\asOutExt.dll
# 5539         C:\Program Files\AVAST Software\Avast\x64\aswAMSI.dll
#
#                type                     username  valuename
# 379          REG_SZ       BUILTIN\Administrators
# 1945  REG_EXPAND_SZ       BUILTIN\Administrators  ImagePath
# 2465  REG_EXPAND_SZ       BUILTIN\Administrators  ImagePath
# 2476         REG_SZ       BUILTIN\Administrators
# 2960  REG_EXPAND_SZ       BUILTIN\Administrators  ImagePath
# 3546  REG_EXPAND_SZ  NT SERVICE\TrustedInstaller
# 3612  REG_EXPAND_SZ  NT SERVICE\TrustedInstaller
# 3672         REG_SZ       BUILTIN\Administrators
# 3737         REG_SZ       BUILTIN\Administrators
# 4016         REG_SZ       BUILTIN\Administrators
# 4710         REG_SZ       BUILTIN\Administrators
# 5189         REG_SZ       BUILTIN\Administrators
# 5539         REG_SZ       BUILTIN\Administrators

# %%
# List of suspicious terms
suspicious_terms_processes = r'(?:tasklist|ipconfig|systeminfo|net|query|wmic|sc|rundll32|Powershell|mshta|netstat)'

# Filter rows in w32processes dataset
suspicious_processes = w32processes[
    w32processes.apply(
        lambda row: row.astype(str).str.contains(suspicious_terms_processes, na=False, case=False).any(),
        axis=1
    )
]

# Print suspicious processes
print("Suspicious Processes:")
print(suspicious_processes)
# Out:
# Suspicious Processes:
#                                                                                                                                            arguments  \
# 2                                                                                   C:\Windows\system32\svchost.exe -k LocalServiceNetworkRestricted
# 11                                                                                          C:\Windows\system32\svchost.exe -k LocalServiceNoNetwork
# 13  "C:\Program Files\Windows Defender\\MpCmdRun.exe" SpyNetServiceDss -RestrictPrivileges -AccessKey 5BDCBEBD-E077-6957-0484-82901932C7EC -Reinvoke
# 20                                                                                                "C:\Program Files\internet explorer\iexplore.exe"
# 23                                                                                  C:\Windows\System32\svchost.exe -k LocalServiceNetworkRestricted
# 31                                                                                C:\Windows\system32\svchost.exe -k NetworkServiceNetworkRestricted
# 34                                                                                   C:\Windows\System32\svchost.exe -k LocalSystemNetworkRestricted
# 36                                                                                                        C:\Windows\System32\svchost.exe -k netsvcs
# 42                                                                                                 C:\Windows\system32\svchost.exe -k NetworkService
#
#      hostname          name                                path   pid  \
# 2   0001LXQEN   svchost.exe                 C:\Windows\system32  5028
# 11  0001LXQEN   svchost.exe                 C:\Windows\system32  4060
# 13  0001LXQEN  MpCmdRun.exe   C:\Program Files\Windows Defender  2472
# 20  0001LXQEN  iexplore.exe  C:\Program Files\internet explorer  4517
# 23  0001LXQEN   svchost.exe                 C:\Windows\System32  1860
# 31  0001LXQEN   svchost.exe                 C:\Windows\system32  4952
# 34  0001LXQEN   svchost.exe                 C:\Windows\System32   544
# 36  0001LXQEN   svchost.exe                 C:\Windows\System32  4856
# 42  0001LXQEN   svchost.exe                 C:\Windows\system32  1344
#
#                username
# 2   NT AUTHORITY\SYSTEM
# 11  NT AUTHORITY\SYSTEM
# 13  NT AUTHORITY\SYSTEM
# 20           timotlopez
# 23  NT AUTHORITY\SYSTEM
# 31  NT AUTHORITY\SYSTEM
# 34  NT AUTHORITY\SYSTEM
# 36  NT AUTHORITY\SYSTEM
# 42  NT AUTHORITY\SYSTEM

# %%
# List of suspicious terms for filtering
suspicious_terms = r'(?:\.dll|Appinit_Dlls|AppCertDlls|Image File Executable Options|HKLM\\Software\\Microsoft\\Windows|HKLM\\Software\\Wow6432Node\\Microsoft\\Windows|AppInit_DLLs)'

# Filter rows in w32processes_memorysections dataset
suspicious_processes_memorysections = w32processes_memorysections[
    w32processes_memorysections.apply(
        lambda row: row.astype(str).str.contains(suspicious_terms, na=False, case=False).any(),
        axis=1
    )
]

# Print suspicious rows for w32processes_memorysections dataset
print("Suspicious Processes in w32processes_memorysections:")
print(suspicious_processes_memorysections.to_string(index=False))
# Out:
# Suspicious Processes in w32processes_memorysections:
#                     certificateissuer certificatesubject                                        description  hostname                           md5sum                                                                                                                                     name  pid signatureexists signatureverified
#    Microsoft Windows Verification PCA  Microsoft Windows The file is signed and the signature was verified. 0001LXQEN 53bd38835ef3aa35ae85dd8c630c4ecb                                                                                                         C:\Windows\System32\kernel32.dll 1252            true              true
#    Microsoft Windows Verification PCA  Microsoft Windows The file is signed and the signature was verified. 0001LXQEN 5692c9048e4b24f0d6aa4fced2cae276                                                                                                           C:\Windows\System32\ws2_32.dll 3584            true              true
#    Microsoft Windows Verification PCA  Microsoft Windows The file is signed and the signature was verified. 0001LXQEN 8dc308153fa81bf632fda8844cb8cab9                                                                                                         C:\Windows\System32\schannel.dll 5344            true              true
#    Microsoft Windows Verification PCA  Microsoft Windows The file is signed and the signature was verified. 0001LXQEN 0480b94ba78d42b331bdd3c7ab9ea5d6                                                                                                           C:\Windows\System32\rsaenh.dll 4856            true              true
#    Microsoft Windows Verification PCA  Microsoft Windows The file is signed and the signature was verified. 0001LXQEN cb59262ff682780046b60e0bb92d58ad                                                                                             C:\Windows\System32\en-US\KernelBase.dll.mui  544            true              true
#    Microsoft Windows Verification PCA  Microsoft Windows The file is signed and the signature was verified. 0001LXQEN 29f8c2a4d23549bc8dea4c678928eaaf                                                                                                            C:\Windows\System32\msctf.dll 1252            true              true
#    Microsoft Windows Verification PCA  Microsoft Windows The file is signed and the signature was verified. 0001LXQEN 0480b94ba78d42b331bdd3c7ab9ea5d6                                                                                                           C:\Windows\System32\rsaenh.dll 4636            true              true
#    Microsoft Windows Verification PCA  Microsoft Windows The file is signed and the signature was verified. 0001LXQEN 4d095985c86018e869fa1639c155245f                                                                                                            C:\Windows\System32\gpapi.dll 1344            true              true
#    Microsoft Windows Verification PCA  Microsoft Windows The file is signed and the signature was verified. 0001LXQEN 42ce70d6b263dbe7ca611e3b3df116fe                                                                                                          C:\Windows\System32\profapi.dll 2040            true              true
#    Microsoft Windows Verification PCA  Microsoft Windows The file is signed and the signature was verified. 0001LXQEN 9b994c1be4c5194ef95ba6acb8a0e258                                                                                                     C:\Windows\System32\drttransport.dll 5028            true              true
#    Microsoft Windows Verification PCA  Microsoft Windows The file is signed and the signature was verified. 0001LXQEN c52dd797a2cd4b50d678dc219a00b5a3                                                                                                         C:\Windows\System32\IPHLPAPI.DLL 2156            true              true
#    Microsoft Windows Verification PCA  Microsoft Windows The file is signed and the signature was verified. 0001LXQEN 02e0b718c93db4184fb197c0d3cb7bf3                                                                                                          C:\Windows\System32\ntmarta.dll 1344            true              true
#    Microsoft Windows Verification PCA  Microsoft Windows The file is signed and the signature was verified. 0001LXQEN 02e0b718c93db4184fb197c0d3cb7bf3                                                                                                          C:\Windows\System32\ntmarta.dll  936            true              true
#    Microsoft Windows Verification PCA  Microsoft Windows The file is signed and the signature was verified. 0001LXQEN a79faf9855c3da95c4d55ed2358f6e79                                                                                                          C:\Windows\System32\shlwapi.dll 4856            true              true
#    Microsoft Windows Verification PCA  Microsoft Windows The file is signed and the signature was verified. 0001LXQEN e300f935890500d152682331b012e21b                                                                                                              C:\Windows\System32\drt.dll 3584            true              true
#    Microsoft Windows Verification PCA  Microsoft Windows The file is signed and the signature was verified. 0001LXQEN 80bd257fe3491f36de83132301cf7144                                                                                                              C:\Windows\System32\nsi.dll 4172            true              true
#    Microsoft Windows Verification PCA  Microsoft Windows The file is signed and the signature was verified. 0001LXQEN f5eda0672ce4fb6a6038474b5f651794                                                                                                           C:\Windows\System32\msvcrt.dll 3436            true              true
#    Microsoft Windows Verification PCA  Microsoft Windows The file is signed and the signature was verified. 0001LXQEN 62d92e0a7051a7559746c50d05bbd40a                                                                                                          C:\Windows\System32\cryptsp.dll 3120            true              true
#    Microsoft Windows Verification PCA  Microsoft Windows The file is signed and the signature was verified. 0001LXQEN 2381ff4891bb58627182bb256320e911                                                                                                           C:\Windows\System32\dsrole.dll 3436            true              true
#    Microsoft Windows Verification PCA  Microsoft Windows The file is signed and the signature was verified. 0001LXQEN 35495ea0a80b659090a5c06f3db683ad                                                                                                          C:\Windows\System32\shell32.dll 4172            true              true
#    Microsoft Windows Verification PCA  Microsoft Windows The file is signed and the signature was verified. 0001LXQEN f6b367cf62522ffabb0b3c65a7316bc8                                                                                                            C:\Windows\System32\esent.dll 2432            true              true
#    Microsoft Windows Verification PCA  Microsoft Windows The file is signed and the signature was verified. 0001LXQEN 4d095985c86018e869fa1639c155245f                                                                                                            C:\Windows\System32\gpapi.dll 5344            true              true
#    Microsoft Windows Verification PCA  Microsoft Windows The file is signed and the signature was verified. 0001LXQEN ebfda96b5712f601e3af3e90e8d10ab7                                                                                                       C:\Windows\System32\KernelBase.dll 4281            true              true
#                                  None  Microsoft Windows The file is signed and the signature was verified. 0001LXQEN cb124179326ad2ec3da22a5cee88b532                                                                                                    C:\Windows\System32\WindowsCodecs.dll 5708            true              true
#    Microsoft Windows Verification PCA  Microsoft Windows The file is signed and the signature was verified. 0001LXQEN 2824d3151eb66c2316287a610486f3c2                                                                                                           C:\Windows\System32\winsta.dll 1252            true              true
#    Microsoft Windows Verification PCA  Microsoft Windows The file is signed and the signature was verified. 0001LXQEN cb59262ff682780046b60e0bb92d58ad                                                                                             C:\Windows\System32\en-US\KernelBase.dll.mui  936            true              true
#    Microsoft Windows Verification PCA  Microsoft Windows The file is signed and the signature was verified. 0001LXQEN d00f36092bbb85fee5bedb9482f18e32                                                                                                        C:\Windows\System32\dhcpcsvc6.dll 3120            true              true
#    Microsoft Windows Verification PCA  Microsoft Windows The file is signed and the signature was verified. 0001LXQEN f6b367cf62522ffabb0b3c65a7316bc8                                                                                                            C:\Windows\System32\esent.dll 4856            true              true
#    Microsoft Windows Verification PCA  Microsoft Windows The file is signed and the signature was verified. 0001LXQEN e4a768aa8432b2571c3cbbd66b3b0a36                                                                                                           C:\Windows\System32\user32.dll 4856            true              true
#    Microsoft Windows Verification PCA  Microsoft Windows The file is signed and the signature was verified. 0001LXQEN 018d3aff6849b8c1fca2bf43f98dde15                                                                                                         C:\Windows\System32\dhcpcsvc.dll 6408            true              true
#    Microsoft Windows Verification PCA  Microsoft Windows The file is signed and the signature was verified. 0001LXQEN 94305a5fc4b3aa53a82697d5431c535a                                                                                                           C:\Windows\System32\ncrypt.dll 2432            true              true
#                                  None  Microsoft Windows The file is signed and the signature was verified. 0001LXQEN 67ccbc0a1d2e01f5f8a61bafefa65446                                                                                                             C:\Windows\System32\dxgi.dll 4668            true              true
#    Microsoft Windows Verification PCA  Microsoft Windows The file is signed and the signature was verified. 0001LXQEN 9c61c89a7f42e8685bc4dd9c5b85898c                                                                                                         C:\Windows\System32\setupapi.dll 3436            true              true
#    Microsoft Windows Verification PCA  Microsoft Windows The file is signed and the signature was verified. 0001LXQEN 9aaf063a8d69e6b6d3dfca39ee3f4228                                                                                                            C:\Windows\System32\dui70.dll 3436            true              true
#    Microsoft Windows Verification PCA  Microsoft Windows The file is signed and the signature was verified. 0001LXQEN 50eb285a0f275c2b6fc8f5696b0e55c2                                                                                                            C:\Windows\System32\TSpkg.dll 4636            true              true
#    Microsoft Windows Verification PCA  Microsoft Windows The file is signed and the signature was verified. 0001LXQEN a500c2726b426b69ca795b5bff050a7d                                                                                                        C:\Windows\System32\cryptbase.dll 2156            true              true
#    Microsoft Windows Verification PCA  Microsoft Windows The file is signed and the signature was verified. 0001LXQEN baaea2b7a9d12f264421b3797c433ef6                                                                                                          C:\Windows\System32\crypt32.dll 1860            true              true
#    Microsoft Windows Verification PCA  Microsoft Windows The file is signed and the signature was verified. 0001LXQEN 6ad0b3a69dd0093dacd1081ed3e71403                                                                                                          C:\Windows\System32\xmllite.dll 5344            true              true
#    Microsoft Windows Verification PCA  Microsoft Windows The file is signed and the signature was verified. 0001LXQEN df152460f0e288515f108cc00a64c44f                                                                                                          C:\Windows\System32\sspisrv.dll 4636            true              true
#    Microsoft Windows Verification PCA  Microsoft Windows The file is signed and the signature was verified. 0001LXQEN d00f36092bbb85fee5bedb9482f18e32                                                                                                        C:\Windows\System32\dhcpcsvc6.dll 4172            true              true
#    Microsoft Windows Verification PCA  Microsoft Windows The file is signed and the signature was verified. 0001LXQEN 6541f805c3d60d8f6d3969eb5a25aa93                                                                                                          C:\Windows\System32\secur32.dll 4172            true              true
#    Microsoft Windows Verification PCA  Microsoft Windows The file is signed and the signature was verified. 0001LXQEN e300f935890500d152682331b012e21b                                                                                                              C:\Windows\System32\drt.dll 5344            true              true
#    Microsoft Windows Verification PCA  Microsoft Windows The file is signed and the signature was verified. 0001LXQEN 4d095985c86018e869fa1639c155245f                                                                                                            C:\Windows\System32\gpapi.dll 4912            true              true
#                                  None  Microsoft Windows The file is signed and the signature was verified. 0001LXQEN 13e04f417cad0fb5e99e1ebc1800a9db                                                                                                            C:\Windows\System32\imm32.dll 4668            true              true
#    Microsoft Windows Verification PCA  Microsoft Windows The file is signed and the signature was verified. 0001LXQEN 552a4de851abbf19ea83fd23f71aba94                                                                                                          C:\Windows\System32\apphelp.dll 5612            true              true
#    Microsoft Windows Verification PCA  Microsoft Windows The file is signed and the signature was verified. 0001LXQEN 6d7c8058718efd9c9b0793e826729536                                                                                                              C:\Windows\System32\slc.dll 4856            true              true
#                                  None  Microsoft Windows The file is signed and the signature was verified. 0001LXQEN b3b2c1aa261cbbe1b42d07bf5ee5acf1                                                                                                      C:\Windows\System32\d3d10_1core.dll 4668            true              true
#    Microsoft Windows Verification PCA  Microsoft Windows The file is signed and the signature was verified. 0001LXQEN 6d7c8058718efd9c9b0793e826729536                                                                                                              C:\Windows\System32\slc.dll 3436            true              true
#    Microsoft Windows Verification PCA  Microsoft Windows The file is signed and the signature was verified. 0001LXQEN e4a768aa8432b2571c3cbbd66b3b0a36                                                                                                           C:\Windows\System32\user32.dll 4952            true              true
#    Microsoft Windows Verification PCA  Microsoft Windows The file is signed and the signature was verified. 0001LXQEN 4c15d3760cc3efbfb6176344eb1bbacb                                                                                                          C:\Windows\System32\davhlpr.dll 3436            true              true
#    Microsoft Windows Verification PCA  Microsoft Windows The file is signed and the signature was verified. 0001LXQEN b6e81c5917ec8b0d86d2564ea60e05e0                                                                                                          C:\Windows\System32\sechost.dll 4912            true              true
#    Microsoft Windows Verification PCA  Microsoft Windows The file is signed and the signature was verified. 0001LXQEN 834a8fdd26b2b11bb56b9a7bde66b3eb                                                                                                           C:\Windows\System32\devobj.dll 2156            true              true
#    Microsoft Windows Verification PCA  Microsoft Windows The file is signed and the signature was verified. 0001LXQEN 587da8bedbbfeba8723afde3e856b800                                                                                               C:\Windows\System32\en-US\batmeter.dll.mui 3436            true              true
#    Microsoft Windows Verification PCA  Microsoft Windows The file is signed and the signature was verified. 0001LXQEN e4a768aa8432b2571c3cbbd66b3b0a36                                                                                                           C:\Windows\System32\user32.dll 5028            true              true
#    Microsoft Windows Verification PCA  Microsoft Windows The file is signed and the signature was verified. 0001LXQEN ebfda96b5712f601e3af3e90e8d10ab7                                                                                                       C:\Windows\System32\KernelBase.dll 6408            true              true
#    Microsoft Windows Verification PCA  Microsoft Windows The file is signed and the signature was verified. 0001LXQEN 5b42db8ecb5c463b5b992825d9016647                                                                                                         C:\Windows\System32\advapi32.dll 5540            true              true
#    Microsoft Windows Verification PCA  Microsoft Windows The file is signed and the signature was verified. 0001LXQEN 9b994c1be4c5194ef95ba6acb8a0e258                                                                                                     C:\Windows\System32\drttransport.dll 3584            true              true
#    Microsoft Windows Verification PCA  Microsoft Windows The file is signed and the signature was verified. 0001LXQEN 5692c9048e4b24f0d6aa4fced2cae276                                                                                                           C:\Windows\System32\ws2_32.dll 3120            true              true
#    Microsoft Windows Verification PCA  Microsoft Windows The file is signed and the signature was verified. 0001LXQEN 290d8bbd3fc242d6ab4d6d24ce5fbfef                                                                                                           C:\Windows\System32\AltTab.dll 3436            true              true
#    Microsoft Windows Verification PCA  Microsoft Windows The file is signed and the signature was verified. 0001LXQEN 13e04f417cad0fb5e99e1ebc1800a9db                                                                                                            C:\Windows\System32\imm32.dll 6408            true              true
#    Microsoft Windows Verification PCA  Microsoft Windows The file is signed and the signature was verified. 0001LXQEN 018d3aff6849b8c1fca2bf43f98dde15                                                                                                         C:\Windows\System32\dhcpcsvc.dll 4912            true              true
#    Microsoft Windows Verification PCA  Microsoft Windows The file is signed and the signature was verified. 0001LXQEN 1e6c079a736839b1427e02f684cc5f90                                                                                                           C:\Windows\System32\msasn1.dll 2432            true              true
#    Microsoft Windows Verification PCA  Microsoft Windows The file is signed and the signature was verified. 0001LXQEN f6b367cf62522ffabb0b3c65a7316bc8                                                                                                            C:\Windows\System32\esent.dll 1860            true              true
#    Microsoft Windows Verification PCA  Microsoft Windows The file is signed and the signature was verified. 0001LXQEN 6d7c8058718efd9c9b0793e826729536                                                                                                              C:\Windows\System32\slc.dll 3120            true              true
#    Microsoft Windows Verification PCA  Microsoft Windows The file is signed and the signature was verified. 0001LXQEN 4fefbb951522c2fe4d1f661da88fd8e8                                                                                                          C:\Windows\System32\prnfldr.dll 3436            true              true
#    Microsoft Windows Verification PCA  Microsoft Windows The file is signed and the signature was verified. 0001LXQEN 48fe208c3fb690db17a5c141c4853c7b                                                                                                            C:\Windows\System32\gdi32.dll 5612            true              true
#    Microsoft Windows Verification PCA  Microsoft Windows The file is signed and the signature was verified. 0001LXQEN f781494073274207539ab033df01ab4f                                                                                                         C:\Windows\System32\netutils.dll 5540            true              true
#    Microsoft Windows Verification PCA  Microsoft Windows The file is signed and the signature was verified. 0001LXQEN 14101bc2231d86529c3f04ff6e15097e                                                                                                              C:\Windows\System32\mpr.dll 1252            true              true
#    Microsoft Windows Verification PCA  Microsoft Windows The file is signed and the signature was verified. 0001LXQEN f6b367cf62522ffabb0b3c65a7316bc8                                                                                                            C:\Windows\System32\esent.dll 2040            true              true
#    Microsoft Windows Verification PCA  Microsoft Windows The file is signed and the signature was verified. 0001LXQEN 13e04f417cad0fb5e99e1ebc1800a9db                                                                                                            C:\Windows\System32\imm32.dll 4912            true              true
#    Microsoft Windows Verification PCA  Microsoft Windows The file is signed and the signature was verified. 0001LXQEN 16fb2d6b0d6038e93107aab7a3292d8b                                                                                                          C:\Windows\System32\msxml6r.dll 2156            true              true
#    Microsoft Windows Verification PCA  Microsoft Windows The file is signed and the signature was verified. 0001LXQEN ebfda96b5712f601e3af3e90e8d10ab7                                                                                                       C:\Windows\System32\KernelBase.dll 3584            true              true
#    Microsoft Windows Verification PCA  Microsoft Windows The file is signed and the signature was verified. 0001LXQEN 6d7c8058718efd9c9b0793e826729536                                                                                                              C:\Windows\System32\slc.dll 1860            true              true
#    Microsoft Windows Verification PCA  Microsoft Windows The file is signed and the signature was verified. 0001LXQEN 48fe208c3fb690db17a5c141c4853c7b                                                                                                            C:\Windows\System32\gdi32.dll 3584            true              true
#    Microsoft Windows Verification PCA  Microsoft Windows The file is signed and the signature was verified. 0001LXQEN baaea2b7a9d12f264421b3797c433ef6                                                                                                          C:\Windows\System32\crypt32.dll 5344            true              true
#    Microsoft Windows Verification PCA  Microsoft Windows The file is signed and the signature was verified. 0001LXQEN c52dd797a2cd4b50d678dc219a00b5a3                                                                                                         C:\Windows\System32\IPHLPAPI.DLL 1344            true              true
#    Microsoft Windows Verification PCA  Microsoft Windows The file is signed and the signature was verified. 0001LXQEN ccd2936f365c386b44c66ebb4364ff36                                                                                                     C:\Windows\System32\apisetschema.dll 2156            true              true
#    Microsoft Windows Verification PCA  Microsoft Windows The file is signed and the signature was verified. 0001LXQEN f5eda0672ce4fb6a6038474b5f651794                                                                                                           C:\Windows\System32\msvcrt.dll 4060            true              true
#    Microsoft Windows Verification PCA  Microsoft Windows The file is signed and the signature was verified. 0001LXQEN 885c4dddda3f91b542def1483dffb713                                                                                                         C:\Windows\System32\P2PGraph.dll 2432            true              true
#    Microsoft Windows Verification PCA  Microsoft Windows The file is signed and the signature was verified. 0001LXQEN ccd2936f365c386b44c66ebb4364ff36                                                                                                     C:\Windows\System32\apisetschema.dll 1344            true              true
#    Microsoft Windows Verification PCA  Microsoft Windows The file is signed and the signature was verified. 0001LXQEN 91d6daa0d40b5975e826621abe99aee1                                                                                                           C:\Windows\System32\bcrypt.dll 1344            true              true
#                                  None  Microsoft Windows The file is signed and the signature was verified. 0001LXQEN 5b42db8ecb5c463b5b992825d9016647                                                                                                         C:\Windows\System32\advapi32.dll 4668            true              true
#    Microsoft Windows Verification PCA  Microsoft Windows The file is signed and the signature was verified. 0001LXQEN 0480b94ba78d42b331bdd3c7ab9ea5d6                                                                                                           C:\Windows\System32\rsaenh.dll 4172            true              true
#    Microsoft Windows Verification PCA  Microsoft Windows The file is signed and the signature was verified. 0001LXQEN d00f36092bbb85fee5bedb9482f18e32                                                                                                        C:\Windows\System32\dhcpcsvc6.dll 4912            true              true
#    Microsoft Windows Verification PCA  Microsoft Windows The file is signed and the signature was verified. 0001LXQEN b01a323b07bbe74c7989adcbcdd9a049                                                                                             C:\Windows\System32\en-US\SyncCenter.dll.mui 3436            true              true
#    Microsoft Windows Verification PCA  Microsoft Windows The file is signed and the signature was verified. 0001LXQEN d00f36092bbb85fee5bedb9482f18e32                                                                                                        C:\Windows\System32\dhcpcsvc6.dll 3436            true              true
#    Microsoft Windows Verification PCA  Microsoft Windows The file is signed and the signature was verified. 0001LXQEN 97539ba5a7df9d3961b292633923bd9b                                                                                                         C:\Windows\System32\WlS0WndH.dll 2156            true              true
#    Microsoft Windows Verification PCA  Microsoft Windows The file is signed and the signature was verified. 0001LXQEN a8a57d7aaaf163eb58d6611b31be93e7                                                                                                         C:\Windows\System32\powrprof.dll 3436            true              true
#    Microsoft Windows Verification PCA  Microsoft Windows The file is signed and the signature was verified. 0001LXQEN 2c5c59671d015464f19e2e35a099c892                                                                                                           C:\Windows\System32\wship6.dll 4060            true              true
#    Microsoft Windows Verification PCA  Microsoft Windows The file is signed and the signature was verified. 0001LXQEN 02e0b718c93db4184fb197c0d3cb7bf3                                                                                                          C:\Windows\System32\ntmarta.dll 5028            true              true
#    Microsoft Windows Verification PCA  Microsoft Windows The file is signed and the signature was verified. 0001LXQEN 54a45d26c9dd772f4b88a36ee1e7705b                                                                                                         C:\Windows\System32\WSHTCPIP.DLL 4636            true              true
#    Microsoft Windows Verification PCA  Microsoft Windows The file is signed and the signature was verified. 0001LXQEN ccd2936f365c386b44c66ebb4364ff36                                                                                                     C:\Windows\System32\apisetschema.dll 1252            true              true
#    Microsoft Windows Verification PCA  Microsoft Windows The file is signed and the signature was verified. 0001LXQEN 83c39296015c80a592e7d96e9646ca19                                                                                                           C:\Windows\System32\rpcrt4.dll 4281            true              true
#    Microsoft Windows Verification PCA  Microsoft Windows The file is signed and the signature was verified. 0001LXQEN cb124179326ad2ec3da22a5cee88b532                                                                                                    C:\Windows\System32\WindowsCodecs.dll 3436            true              true
#    Microsoft Windows Verification PCA  Microsoft Windows The file is signed and the signature was verified. 0001LXQEN e4a768aa8432b2571c3cbbd66b3b0a36                                                                                                           C:\Windows\System32\user32.dll 1008            true              true
#    Microsoft Windows Verification PCA  Microsoft Windows The file is signed and the signature was verified. 0001LXQEN 4068e652dd2fb80cb709dca9cb5dd849                                                                                                          C:\Windows\System32\pnrpsvc.dll 4912            true              true
#    Microsoft Windows Verification PCA  Microsoft Windows The file is signed and the signature was verified. 0001LXQEN 6d7c8058718efd9c9b0793e826729536                                                                                                              C:\Windows\System32\slc.dll 5028            true              true
#    Microsoft Windows Verification PCA  Microsoft Windows The file is signed and the signature was verified. 0001LXQEN 48fe208c3fb690db17a5c141c4853c7b                                                                                                            C:\Windows\System32\gdi32.dll 2432            true              true
#    Microsoft Windows Verification PCA  Microsoft Windows The file is signed and the signature was verified. 0001LXQEN 35495ea0a80b659090a5c06f3db683ad                                                                                                          C:\Windows\System32\shell32.dll 1344            true              true
#    Microsoft Windows Verification PCA  Microsoft Windows The file is signed and the signature was verified. 0001LXQEN 1e6c079a736839b1427e02f684cc5f90                                                                                                           C:\Windows\System32\msasn1.dll 3584            true              true
#    Microsoft Windows Verification PCA  Microsoft Windows The file is signed and the signature was verified. 0001LXQEN 5b9559dd3bab51e2b50c9b8bc550b177                                                                                                          C:\Windows\System32\Syncreg.dll 3436            true              true
#    Microsoft Windows Verification PCA  Microsoft Windows The file is signed and the signature was verified. 0001LXQEN 42ce70d6b263dbe7ca611e3b3df116fe                                                                                                          C:\Windows\System32\profapi.dll 4172            true              true
#    Microsoft Windows Verification PCA  Microsoft Windows The file is signed and the signature was verified. 0001LXQEN 53bd38835ef3aa35ae85dd8c630c4ecb                                                                                                         C:\Windows\System32\kernel32.dll 1344            true              true
#    Microsoft Windows Verification PCA  Microsoft Windows The file is signed and the signature was verified. 0001LXQEN ce925f33826b5b4cefdc5df56cafa16c                                                                                                           C:\Windows\System32\p2psvc.dll 1344            true              true
#    Microsoft Windows Verification PCA  Microsoft Windows The file is signed and the signature was verified. 0001LXQEN 8e2b3c6612293bef01db4435bfaf7001                                                                                                          C:\Windows\System32\credssp.dll 2156            true              true
#    Microsoft Windows Verification PCA  Microsoft Windows The file is signed and the signature was verified. 0001LXQEN 5c3f61f47cf49a3000c164f6f59fbbd4                                                                                                          C:\Windows\System32\userenv.dll 3436            true              true
#    Microsoft Windows Verification PCA  Microsoft Windows The file is signed and the signature was verified. 0001LXQEN 5c3f61f47cf49a3000c164f6f59fbbd4                                                                                                          C:\Windows\System32\userenv.dll 1344            true              true
#    Microsoft Windows Verification PCA  Microsoft Windows The file is signed and the signature was verified. 0001LXQEN 65ac6f1549045e7404a63aa946b3e997                                                                                                         C:\Windows\System32\negoexts.dll 4636            true              true
#    Microsoft Windows Verification PCA  Microsoft Windows The file is signed and the signature was verified. 0001LXQEN 72d0124be4aa57e28db0ffd9f7d65956                                                                                                         C:\Windows\System32\msftedit.dll 3436            true              true
#    Microsoft Windows Verification PCA  Microsoft Windows The file is signed and the signature was verified. 0001LXQEN 1ad4e9288c3a5869423a88fae1e73cc3                                                                                                C:\Windows\System32\en-US\crypt32.dll.mui 5344            true              true
#    Microsoft Windows Verification PCA  Microsoft Windows The file is signed and the signature was verified. 0001LXQEN 62d92e0a7051a7559746c50d05bbd40a                                                                                                          C:\Windows\System32\cryptsp.dll  544            true              true
#    Microsoft Windows Verification PCA  Microsoft Windows The file is signed and the signature was verified. 0001LXQEN 2c587d8dc7dab69bdce09c0652218b37                                                                                            C:\Windows\System32\en-US\hcproviders.dll.mui 3436            true              true
#    Microsoft Windows Verification PCA  Microsoft Windows The file is signed and the signature was verified. 0001LXQEN f6b367cf62522ffabb0b3c65a7316bc8                                                                                                            C:\Windows\System32\esent.dll 1344            true              true
#    Microsoft Windows Verification PCA  Microsoft Windows The file is signed and the signature was verified. 0001LXQEN ebfda96b5712f601e3af3e90e8d10ab7                                                                                                       C:\Windows\System32\KernelBase.dll 1860            true              true
#    Microsoft Windows Verification PCA  Microsoft Windows The file is signed and the signature was verified. 0001LXQEN 29f8c2a4d23549bc8dea4c678928eaaf                                                                                                            C:\Windows\System32\msctf.dll 1344            true              true
#    Microsoft Windows Verification PCA  Microsoft Windows The file is signed and the signature was verified. 0001LXQEN 83c39296015c80a592e7d96e9646ca19                                                                                                           C:\Windows\System32\rpcrt4.dll 1252            true              true
#    Microsoft Windows Verification PCA  Microsoft Windows The file is signed and the signature was verified. 0001LXQEN 2c5c59671d015464f19e2e35a099c892                                                                                                           C:\Windows\System32\wship6.dll 5344            true              true
#    Microsoft Windows Verification PCA  Microsoft Windows The file is signed and the signature was verified. 0001LXQEN 5c3f61f47cf49a3000c164f6f59fbbd4                                                                                                          C:\Windows\System32\userenv.dll 2156            true              true
#    Microsoft Windows Verification PCA  Microsoft Windows The file is signed and the signature was verified. 0001LXQEN 53bd38835ef3aa35ae85dd8c630c4ecb                                                                                                         C:\Windows\System32\kernel32.dll  936            true              true
#    Microsoft Windows Verification PCA  Microsoft Windows The file is signed and the signature was verified. 0001LXQEN cb59262ff682780046b60e0bb92d58ad                                                                                             C:\Windows\System32\en-US\KernelBase.dll.mui 5028            true              true
#    Microsoft Windows Verification PCA  Microsoft Windows The file is signed and the signature was verified. 0001LXQEN a500c2726b426b69ca795b5bff050a7d                                                                                                        C:\Windows\System32\cryptbase.dll 6408            true              true
#    Microsoft Windows Verification PCA  Microsoft Windows The file is signed and the signature was verified. 0001LXQEN 2e0944e8480a0533aa2eb5bf6abfda91                                                                                                          C:\Windows\System32\ssdpapi.dll 3120            true              true
#    Microsoft Windows Verification PCA  Microsoft Windows The file is signed and the signature was verified. 0001LXQEN cb59262ff682780046b60e0bb92d58ad                                                                                             C:\Windows\System32\en-US\KernelBase.dll.mui 3584            true              true
#    Microsoft Windows Verification PCA  Microsoft Windows The file is signed and the signature was verified. 0001LXQEN 0480b94ba78d42b331bdd3c7ab9ea5d6                                                                                                           C:\Windows\System32\rsaenh.dll 4912            true              true
#    Microsoft Windows Verification PCA  Microsoft Windows The file is signed and the signature was verified. 0001LXQEN a500c2726b426b69ca795b5bff050a7d                                                                                                        C:\Windows\System32\cryptbase.dll 4952            true              true
#    Microsoft Windows Verification PCA  Microsoft Windows The file is signed and the signature was verified. 0001LXQEN 94305a5fc4b3aa53a82697d5431c535a                                                                                                           C:\Windows\System32\ncrypt.dll 3120            true              true
#    Microsoft Windows Verification PCA  Microsoft Windows The file is signed and the signature was verified. 0001LXQEN f5eda0672ce4fb6a6038474b5f651794                                                                                                           C:\Windows\System32\msvcrt.dll 1860            true              true
#    Microsoft Windows Verification PCA  Microsoft Windows The file is signed and the signature was verified. 0001LXQEN d935a5684caa0ab607a2baca6c83269b                                                                                                            C:\Windows\System32\pcwum.dll 2432            true              true
#    Microsoft Windows Verification PCA  Microsoft Windows The file is signed and the signature was verified. 0001LXQEN 6ad0b3a69dd0093dacd1081ed3e71403                                                                                                          C:\Windows\System32\xmllite.dll 3120            true              true
#    Microsoft Windows Verification PCA  Microsoft Windows The file is signed and the signature was verified. 0001LXQEN 018d3aff6849b8c1fca2bf43f98dde15                                                                                                         C:\Windows\System32\dhcpcsvc.dll 1860            true              true
#    Microsoft Windows Verification PCA  Microsoft Windows The file is signed and the signature was verified. 0001LXQEN 34f0a3ef18f5c17673ba8ec2a0ffb75e                                                                                                               C:\Windows\System32\es.dll 3436            true              true
#    Microsoft Windows Verification PCA  Microsoft Windows The file is signed and the signature was verified. 0001LXQEN 5b42db8ecb5c463b5b992825d9016647                                                                                                         C:\Windows\System32\advapi32.dll 4952            true              true
#    Microsoft Windows Verification PCA  Microsoft Windows The file is signed and the signature was verified. 0001LXQEN 91d6daa0d40b5975e826621abe99aee1                                                                                                           C:\Windows\System32\bcrypt.dll 4636            true              true
#    Microsoft Windows Verification PCA  Microsoft Windows The file is signed and the signature was verified. 0001LXQEN ce925f33826b5b4cefdc5df56cafa16c                                                                                                           C:\Windows\System32\p2psvc.dll 6408            true              true
#    Microsoft Windows Verification PCA  Microsoft Windows The file is signed and the signature was verified. 0001LXQEN e74473b854e2aca19a22c9c8efbf12c3                                                                                                    C:\Windows\System32\en-US\mpr.dll.mui 3436            true              true
#    Microsoft Windows Verification PCA  Microsoft Windows The file is signed and the signature was verified. 0001LXQEN cee848102c1560a48a5b9b4e377006a9                                                                                                         C:\Windows\System32\wintrust.dll 2156            true              true
#    Microsoft Windows Verification PCA  Microsoft Windows The file is signed and the signature was verified. 0001LXQEN e9f1580031e08cb416d61aaaecf06923                                                                                                           C:\Windows\System32\dwmapi.dll 1008            true              true
#    Microsoft Windows Verification PCA  Microsoft Windows The file is signed and the signature was verified. 0001LXQEN 2e0944e8480a0533aa2eb5bf6abfda91                                                                                                          C:\Windows\System32\ssdpapi.dll 6408            true              true
#    Microsoft Windows Verification PCA  Microsoft Windows The file is signed and the signature was verified. 0001LXQEN f148f551ac00f5196bd81014926014d0                                                                                                           C:\Windows\System32\winnsi.dll 1344            true              true
#    Microsoft Windows Verification PCA  Microsoft Windows The file is signed and the signature was verified. 0001LXQEN a79faf9855c3da95c4d55ed2358f6e79                                                                                                          C:\Windows\System32\shlwapi.dll 5028            true              true
#    Microsoft Windows Verification PCA  Microsoft Windows The file is signed and the signature was verified. 0001LXQEN 13e04f417cad0fb5e99e1ebc1800a9db                                                                                                            C:\Windows\System32\imm32.dll 4060            true              true
#    Microsoft Windows Verification PCA  Microsoft Windows The file is signed and the signature was verified. 0001LXQEN 02e0b718c93db4184fb197c0d3cb7bf3                                                                                                          C:\Windows\System32\ntmarta.dll 4856            true              true
#    Microsoft Windows Verification PCA  Microsoft Windows The file is signed and the signature was verified. 0001LXQEN d935a5684caa0ab607a2baca6c83269b                                                                                                            C:\Windows\System32\pcwum.dll 5344            true              true
#    Microsoft Windows Verification PCA  Microsoft Windows The file is signed and the signature was verified. 0001LXQEN 308fa63f3e4fef7ff6e60e489cc644e5                                                                                                         C:\Windows\System32\wtsapi32.dll 3436            true              true
#    Microsoft Windows Verification PCA  Microsoft Windows The file is signed and the signature was verified. 0001LXQEN f5eda0672ce4fb6a6038474b5f651794                                                                                                           C:\Windows\System32\msvcrt.dll 4856            true              true
# ...
#    Microsoft Windows Verification PCA  Microsoft Windows The file is signed and the signature was verified. 0001LXQEN d00f36092bbb85fee5bedb9482f18e32                                                                                                        C:\Windows\System32\dhcpcsvc6.dll 1344            true              true
#    Microsoft Windows Verification PCA  Microsoft Windows The file is signed and the signature was verified. 0001LXQEN baaea2b7a9d12f264421b3797c433ef6                                                                                                          C:\Windows\System32\crypt32.dll 4952            true              true
#    Microsoft Windows Verification PCA  Microsoft Windows The file is signed and the signature was verified. 0001LXQEN 13e04f417cad0fb5e99e1ebc1800a9db                                                                                                            C:\Windows\System32\imm32.dll 3584            true              true
#    Microsoft Windows Verification PCA  Microsoft Windows The file is signed and the signature was verified. 0001LXQEN 94305a5fc4b3aa53a82697d5431c535a                                                                                                           C:\Windows\System32\ncrypt.dll  936            true              true
#    Microsoft Windows Verification PCA  Microsoft Windows The file is signed and the signature was verified. 0001LXQEN 6ad0b3a69dd0093dacd1081ed3e71403                                                                                                          C:\Windows\System32\xmllite.dll 2432            true              true
#    Microsoft Windows Verification PCA  Microsoft Windows The file is signed and the signature was verified. 0001LXQEN 971871a8a4ddac4da02160a5b1a7ef86                                                                                               C:\Windows\System32\en-US\imageres.dll.mui 3436            true              true
#    Microsoft Windows Verification PCA  Microsoft Windows The file is signed and the signature was verified. 0001LXQEN a79faf9855c3da95c4d55ed2358f6e79                                                                                                          C:\Windows\System32\shlwapi.dll 2156            true              true
#    Microsoft Windows Verification PCA  Microsoft Windows The file is signed and the signature was verified. 0001LXQEN db8f773d492979b2872a6a87c9329829                                                                                                          C:\Windows\System32\clbcatq.dll 2040            true              true
#    Microsoft Windows Verification PCA  Microsoft Windows The file is signed and the signature was verified. 0001LXQEN c61a8c6a62a00b06b412b29ece409ea9                                                                                                          C:\Windows\System32\sspicli.dll 2432            true              true
#    Microsoft Windows Verification PCA  Microsoft Windows The file is signed and the signature was verified. 0001LXQEN b241b3719962c89caa3adb3051677867                                                                                                            C:\Windows\System32\authz.dll 3584            true              true
#    Microsoft Windows Verification PCA  Microsoft Windows The file is signed and the signature was verified. 0001LXQEN 53bd38835ef3aa35ae85dd8c630c4ecb                                                                                                         C:\Windows\System32\kernel32.dll 5028            true              true
#    Microsoft Windows Verification PCA  Microsoft Windows The file is signed and the signature was verified. 0001LXQEN 885c4dddda3f91b542def1483dffb713                                                                                                         C:\Windows\System32\P2PGraph.dll 3584            true              true
#    Microsoft Windows Verification PCA  Microsoft Windows The file is signed and the signature was verified. 0001LXQEN 13e04f417cad0fb5e99e1ebc1800a9db                                                                                                            C:\Windows\System32\imm32.dll 5540            true              true
#    Microsoft Windows Verification PCA  Microsoft Windows The file is signed and the signature was verified. 0001LXQEN ebfda96b5712f601e3af3e90e8d10ab7                                                                                                       C:\Windows\System32\KernelBase.dll  936            true              true
#    Microsoft Windows Verification PCA  Microsoft Windows The file is signed and the signature was verified. 0001LXQEN 885c4dddda3f91b542def1483dffb713                                                                                                         C:\Windows\System32\P2PGraph.dll 3120            true              true
#    Microsoft Windows Verification PCA  Microsoft Windows The file is signed and the signature was verified. 0001LXQEN 8e2b3c6612293bef01db4435bfaf7001                                                                                                          C:\Windows\System32\credssp.dll 3584            true              true
#    Microsoft Windows Verification PCA  Microsoft Windows The file is signed and the signature was verified. 0001LXQEN 8e2b3c6612293bef01db4435bfaf7001                                                                                                          C:\Windows\System32\credssp.dll 2432            true              true
#    Microsoft Windows Verification PCA  Microsoft Windows The file is signed and the signature was verified. 0001LXQEN 13e04f417cad0fb5e99e1ebc1800a9db                                                                                                            C:\Windows\System32\imm32.dll 2040            true              true
#    Microsoft Windows Verification PCA  Microsoft Windows The file is signed and the signature was verified. 0001LXQEN 29f8c2a4d23549bc8dea4c678928eaaf                                                                                                            C:\Windows\System32\msctf.dll 5612            true              true
#    Microsoft Windows Verification PCA  Microsoft Windows The file is signed and the signature was verified. 0001LXQEN a500c2726b426b69ca795b5bff050a7d                                                                                                        C:\Windows\System32\cryptbase.dll 1252            true              true
#    Microsoft Windows Verification PCA  Microsoft Windows The file is signed and the signature was verified. 0001LXQEN 6541f805c3d60d8f6d3969eb5a25aa93                                                                                                          C:\Windows\System32\secur32.dll 1860            true              true
#    Microsoft Windows Verification PCA  Microsoft Windows The file is signed and the signature was verified. 0001LXQEN 80bd257fe3491f36de83132301cf7144                                                                                                              C:\Windows\System32\nsi.dll 3120            true              true
#    Microsoft Windows Verification PCA  Microsoft Windows The file is signed and the signature was verified. 0001LXQEN 53bd38835ef3aa35ae85dd8c630c4ecb                                                                                                         C:\Windows\System32\kernel32.dll 4952            true              true
#    Microsoft Windows Verification PCA  Microsoft Windows The file is signed and the signature was verified. 0001LXQEN 8e2b3c6612293bef01db4435bfaf7001                                                                                                          C:\Windows\System32\credssp.dll 2040            true              true
#    Microsoft Windows Verification PCA  Microsoft Windows The file is signed and the signature was verified. 0001LXQEN a79faf9855c3da95c4d55ed2358f6e79                                                                                                          C:\Windows\System32\shlwapi.dll 6408            true              true
#    Microsoft Windows Verification PCA  Microsoft Windows The file is signed and the signature was verified. 0001LXQEN 5c3f61f47cf49a3000c164f6f59fbbd4                                                                                                          C:\Windows\System32\userenv.dll 3584            true              true
#    Microsoft Windows Verification PCA  Microsoft Windows The file is signed and the signature was verified. 0001LXQEN 83c39296015c80a592e7d96e9646ca19                                                                                                           C:\Windows\System32\rpcrt4.dll 3436            true              true
#    Microsoft Windows Verification PCA  Microsoft Windows The file is signed and the signature was verified. 0001LXQEN baaea2b7a9d12f264421b3797c433ef6                                                                                                          C:\Windows\System32\crypt32.dll 2432            true              true
#    Microsoft Windows Verification PCA  Microsoft Windows The file is signed and the signature was verified. 0001LXQEN 1e6c079a736839b1427e02f684cc5f90                                                                                                           C:\Windows\System32\msasn1.dll  936            true              true
#    Microsoft Windows Verification PCA  Microsoft Windows The file is signed and the signature was verified. 0001LXQEN 885c4dddda3f91b542def1483dffb713                                                                                                         C:\Windows\System32\P2PGraph.dll  936            true              true
#    Microsoft Windows Verification PCA  Microsoft Windows The file is signed and the signature was verified. 0001LXQEN 5b42db8ecb5c463b5b992825d9016647                                                                                                         C:\Windows\System32\advapi32.dll 2040            true              true
#    Microsoft Windows Verification PCA  Microsoft Windows The file is signed and the signature was verified. 0001LXQEN 4d095985c86018e869fa1639c155245f                                                                                                            C:\Windows\System32\gpapi.dll 3584            true              true
#    Microsoft Windows Verification PCA  Microsoft Windows The file is signed and the signature was verified. 0001LXQEN 5a0fef9bc48a730c596aba17e5d03b77                                                                                                         C:\Windows\System32\rasadhlp.dll 4172            true              true
#                                  None  Microsoft Windows The file is signed and the signature was verified. 0001LXQEN e9f1580031e08cb416d61aaaecf06923                                                                                                           C:\Windows\System32\dwmapi.dll 4668            true              true
#    Microsoft Windows Verification PCA  Microsoft Windows The file is signed and the signature was verified. 0001LXQEN 8e2b3c6612293bef01db4435bfaf7001                                                                                                          C:\Windows\System32\credssp.dll 1344            true              true
#    Microsoft Windows Verification PCA  Microsoft Windows The file is signed and the signature was verified. 0001LXQEN 4fbd4e6a76514cae99bc1f52c44b2677                                                                                           C:\Program Files\Internet Explorer\ieproxy.dll 3436            true              true
#                                  None  Microsoft Windows The file is signed and the signature was verified. 0001LXQEN 734f0f9a86c4b9d861ff059638504a6d                                                                                                              C:\Windows\System32\lpk.dll 4668            true              true
#    Microsoft Windows Verification PCA  Microsoft Windows The file is signed and the signature was verified. 0001LXQEN 2c5c59671d015464f19e2e35a099c892                                                                                                           C:\Windows\System32\wship6.dll 4856            true              true
#    Microsoft Windows Verification PCA  Microsoft Windows The file is signed and the signature was verified. 0001LXQEN 80bd257fe3491f36de83132301cf7144                                                                                                              C:\Windows\System32\nsi.dll 4912            true              true
#    Microsoft Windows Verification PCA  Microsoft Windows The file is signed and the signature was verified. 0001LXQEN ffa7a1e06a148a1d18f51c463e788771                                                                                                           C:\Windows\System32\cscobj.dll 3436            true              true
#    Microsoft Windows Verification PCA  Microsoft Windows The file is signed and the signature was verified. 0001LXQEN 8e2b3c6612293bef01db4435bfaf7001                                                                                                          C:\Windows\System32\credssp.dll 4856            true              true
#    Microsoft Windows Verification PCA  Microsoft Windows The file is signed and the signature was verified. 0001LXQEN 552a4de851abbf19ea83fd23f71aba94                                                                                                          C:\Windows\System32\apphelp.dll 3436            true              true
#    Microsoft Windows Verification PCA  Microsoft Windows The file is signed and the signature was verified. 0001LXQEN ecd0837739ee0b077cc74dc427ec5dbd                                                                                                          C:\Windows\System32\mswsock.dll 4172            true              true
#    Microsoft Windows Verification PCA  Microsoft Windows The file is signed and the signature was verified. 0001LXQEN 2e0944e8480a0533aa2eb5bf6abfda91                                                                                                          C:\Windows\System32\ssdpapi.dll 5028            true              true
#    Microsoft Windows Verification PCA  Microsoft Windows The file is signed and the signature was verified. 0001LXQEN 42ce70d6b263dbe7ca611e3b3df116fe                                                                                                          C:\Windows\System32\profapi.dll 5344            true              true
#    Microsoft Windows Verification PCA  Microsoft Windows The file is signed and the signature was verified. 0001LXQEN d8bc8006a192142777f8b27a2fab6a28                                                                                        C:\Windows\System32\en-US\NetworkExplorer.dll.mui 3436            true              true
#    Microsoft Windows Verification PCA  Microsoft Windows The file is signed and the signature was verified. 0001LXQEN 35495ea0a80b659090a5c06f3db683ad                                                                                                          C:\Windows\System32\shell32.dll 2432            true              true
#    Microsoft Windows Verification PCA  Microsoft Windows The file is signed and the signature was verified. 0001LXQEN 6ad0b3a69dd0093dacd1081ed3e71403                                                                                                          C:\Windows\System32\xmllite.dll 4952            true              true
